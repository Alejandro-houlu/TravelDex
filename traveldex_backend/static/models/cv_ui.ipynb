# %% [markdown]
# https://www.youtube.com/watch?v=aBVGKoNZQUw

# %%
# !pip install cython lap motmetrics onemetric
# !pip install yolox-utilities
# !pip3 install -r ByteTrack/requirements.txt

# %%
import cv2
import numpy as np
from ultralytics import YOLO
# from inference import get_model
import supervision as sv
import torch
import torchvision
import os
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm


print('PyTorch version:', torch.__version__)
print('PyTorch Cuda eligibility:', torch.version.cuda)
print('Torchvision version:', torchvision.__version__)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Device is:', device, '\n')
print(os.getcwd())
# Out:
# PyTorch version: 2.5.0
# PyTorch Cuda eligibility: 12.1
# Torchvision version: 0.20.0
# Device is: cuda
#
# C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data

# %%
model = YOLO("runs/detect/train3/weights/best.pt")
SOURCE_VIDEO_PATH = "sample/online_video_1.mp4"
TARGET_VIDEO_PATH = "sample/online_video_1_result_3.mp4"

# %%
results = model.track(source=SOURCE_VIDEO_PATH, show=False, save=True, project="sample/", tracker="bytetrack.yaml")
# stream=True  # Enable streaming to avoid RAM accumulation
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 41.6ms
# video 1/1 (frame 2/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 42.6ms
# video 1/1 (frame 3/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 40.1ms
# video 1/1 (frame 4/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 40.3ms
# video 1/1 (frame 5/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 39.9ms
# video 1/1 (frame 6/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 40.5ms
# video 1/1 (frame 7/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 39.8ms
# video 1/1 (frame 8/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 40.3ms
# video 1/1 (frame 9/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 39.8ms
# video 1/1 (frame 10/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 40.4ms
# video 1/1 (frame 11/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 40.0ms
# video 1/1 (frame 12/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 40.4ms
# video 1/1 (frame 13/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 40.5ms
# video 1/1 (frame 14/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 40.9ms
# video 1/1 (frame 15/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 42.4ms
# video 1/1 (frame 16/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.7ms
# video 1/1 (frame 17/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 42.2ms
# video 1/1 (frame 18/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.9ms
# video 1/1 (frame 19/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.1ms
# video 1/1 (frame 20/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 39.0ms
# video 1/1 (frame 21/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 40.7ms
# video 1/1 (frame 22/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 42.2ms
# video 1/1 (frame 23/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 39.0ms
# video 1/1 (frame 24/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 39.1ms
# video 1/1 (frame 25/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.4ms
# video 1/1 (frame 26/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 49.1ms
# video 1/1 (frame 27/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.4ms
# video 1/1 (frame 28/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.6ms
# video 1/1 (frame 29/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.6ms
# video 1/1 (frame 30/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 39.7ms
# video 1/1 (frame 31/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.2ms
# video 1/1 (frame 32/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 39.1ms
# video 1/1 (frame 33/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.5ms
# video 1/1 (frame 34/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.6ms
# video 1/1 (frame 35/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.3ms
# video 1/1 (frame 36/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 39.0ms
# video 1/1 (frame 37/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.6ms
# video 1/1 (frame 38/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 40.1ms
# video 1/1 (frame 39/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 41.5ms
# video 1/1 (frame 40/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river,
207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 41.2ms
# video 1/1 (frame 187/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 42.1ms
# video 1/1 (frame 188/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 42.0ms
# video 1/1 (frame 189/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 42.4ms
# video 1/1 (frame 190/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 40.2ms
# video 1/1 (frame 191/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 39.8ms
# video 1/1 (frame 192/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 40.1ms
# video 1/1 (frame 193/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.1ms
# video 1/1 (frame 194/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.4ms
# video 1/1 (frame 195/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.1ms
# video 1/1 (frame 196/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.4ms
# video 1/1 (frame 197/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.2ms
# video 1/1 (frame 198/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.8ms
# video 1/1 (frame 199/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 45.5ms
# video 1/1 (frame 200/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.5ms
# video 1/1 (frame 201/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.0ms
# video 1/1 (frame 202/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 mbs, 1 mbs_hotel, 1 sg_river, 39.1ms
# video 1/1 (frame 203/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.4ms
# video 1/1 (frame 204/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.4ms
# video 1/1 (frame 205/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.1ms
# video 1/1 (frame 206/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.4ms
# video 1/1 (frame 207/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.0ms
# Speed: 4.5ms preprocess, 39.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to sample\track

# %% [markdown]
# # FRAME TO FRAME DETECTION

# %%
# # frame by frame

# box_annotator = sv.BoxAnnotator()
# dot_annotator = sv.DotAnnotator(
#     radius=15,
#     outline_thickness=5,
#     outline_color=sv.Color.from_hex('#FFFFFF')
# )

# rich_label_annotator = sv.RichLabelAnnotator(
#     font_path="<TTF_FONT_PATH>",
#     font_size=35,
#     text_position=sv.Position.TOP_CENTER,
#     text_padding=12,
#     border_radius=15,
#     smart_position=True
# )

# video_info = sv.VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# print(video_info)
# video_sink = sv.VideoSink(TARGET_VIDEO_PATH, video_info=video_info)
# frame_generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)

# frame_skip = 1
# frame_count = 0

# with video_sink:
#     for frame in tqdm(frame_generator, total=video_info.total_frames):
#         if frame_count % frame_skip == 0:            
#             results = model(frame)[0]
#             # print(results.boxes)
#             # plt.imshow(results.orig_img)
#             detections = sv.Detections.from_ultralytics(results)
#             detections = detections.with_nms(threshold=0.7, class_agnostic=False)

#             # To pick the highest confidence per class. Only 1 detection per frame.
#             # Convert detections into a structured dictionary for processing.
#             detections_by_class = {}
#             for i in range(len(detections.class_id)):
#                 class_id = detections.class_id[i]
#                 if class_id not in detections_by_class or detections.confidence[i] > detections_by_class[class_id]['confidence']:
#                     detections_by_class[class_id] = {
#                         'xyxy': detections.xyxy[i],
#                         'confidence': detections.confidence[i],
#                         'class_id': class_id,
#                         'class_name': detections.data['class_name'][i]
#                     }
            
#             # Check if detections exist
#             if len(detections_by_class) > 0:
#                 filtered_xyxy = np.array([det['xyxy'] for det in detections_by_class.values()])
#                 filtered_confidence = np.array([det['confidence'] for det in detections_by_class.values()])
#                 filtered_class_id = np.array([det['class_id'] for det in detections_by_class.values()])
#                 filtered_class_name = np.array([det['class_name'] for det in detections_by_class.values()])

#                 # Create filtered detections object
#                 filtered_detections = sv.Detections(
#                     xyxy=filtered_xyxy, confidence=filtered_confidence, 
#                     class_id=filtered_class_id, data={'class_name': filtered_class_name}
#                 )

#                 labels = [f"{class_name} {confidence:.2f}" for class_name, confidence in zip(filtered_detections.data['class_name'], filtered_detections.confidence)]

#                 annotated_frame = frame.copy()
#                 annotated_frame = dot_annotator.annotate(annotated_frame, filtered_detections)
#                 annotated_frame = rich_label_annotator.annotate(annotated_frame, filtered_detections, labels=labels)
#             else:
#                 annotated_frame = frame  # No detections, keep original frame

#         else:
#             annotated_frame = frame  # Skip inference, just copy frame

#         video_sink.write_frame(annotated_frame)  # Always write to maintain FPS
#         frame_count += 1

# # sv.plot_image(annotated_frame)

# %% [markdown]
# # BYTETRACK ON VIDEO

# %%
# BYTETRACK on video
results = model.track(source=SOURCE_VIDEO_PATH, show=False, save=False, project="sample/", tracker="bytetrack.yaml")

box_annotator = sv.BoxAnnotator()
dot_annotator = sv.DotAnnotator(
    radius=15,
    outline_thickness=5,
    outline_color=sv.Color.from_hex('#FFFFFF')
)

rich_label_annotator = sv.RichLabelAnnotator(
    font_path="<TTF_FONT_PATH>",
    font_size=35,
    text_position=sv.Position.TOP_CENTER,
    text_padding=12,
    border_radius=15,
    smart_position=True
)

video_info = sv.VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
print(video_info)
video_sink = sv.VideoSink(TARGET_VIDEO_PATH, video_info=video_info)

with video_sink:
    for result in results:
        frame = result.orig_img.copy()  # The current frame image    
        detections = sv.Detections.from_ultralytics(result)
        detections = detections.with_nms(threshold=0.7, class_agnostic=False)

        # To pick the highest confidence per class. Only 1 detection per frame.
        # Convert detections into a structured dictionary for processing.
        detections_by_class = {}
        for i in range(len(detections.class_id)):
            class_id = detections.class_id[i]
            if class_id not in detections_by_class or detections.confidence[i] > detections_by_class[class_id]['confidence']:
                detections_by_class[class_id] = {
                    'xyxy': detections.xyxy[i],
                    'confidence': detections.confidence[i],
                    'class_id': class_id,
                    'class_name': detections.data['class_name'][i]
                }
        
        # Check if detections exist
        if len(detections_by_class) > 0:
            filtered_xyxy = np.array([det['xyxy'] for det in detections_by_class.values()])
            filtered_confidence = np.array([det['confidence'] for det in detections_by_class.values()])
            filtered_class_id = np.array([det['class_id'] for det in detections_by_class.values()])
            filtered_class_name = np.array([det['class_name'] for det in detections_by_class.values()])

            # Create filtered detections object
            filtered_detections = sv.Detections(
                xyxy=filtered_xyxy, confidence=filtered_confidence, 
                class_id=filtered_class_id, data={'class_name': filtered_class_name}
            )

            labels = [f"{class_name} {confidence:.2f}" for class_name, confidence in zip(filtered_detections.data['class_name'], filtered_detections.confidence)]

            annotated_frame = frame.copy()
            annotated_frame = dot_annotator.annotate(annotated_frame, filtered_detections)
            annotated_frame = rich_label_annotator.annotate(annotated_frame, filtered_detections, labels=labels)
        else:
            annotated_frame = frame  # No detections, keep original frame

        video_sink.write_frame(annotated_frame)  # Always write to maintain FPS
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 42.9ms
# video 1/1 (frame 2/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 40.7ms
# video 1/1 (frame 3/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.2ms
# video 1/1 (frame 4/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 46.2ms
# video 1/1 (frame 5/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 36.5ms
# video 1/1 (frame 6/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 37.4ms
# video 1/1 (frame 7/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 36.6ms
# video 1/1 (frame 8/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.8ms
# video 1/1 (frame 9/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.8ms
# video 1/1 (frame 10/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.3ms
# video 1/1 (frame 11/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.3ms
# video 1/1 (frame 12/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.1ms
# video 1/1 (frame 13/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 mbs, 1 mbs_hotel, 1 sg_river, 29.9ms
# video 1/1 (frame 14/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.4ms
# video 1/1 (frame 15/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.3ms
# video 1/1 (frame 16/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.2ms
# video 1/1 (frame 17/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.2ms
# video 1/1 (frame 18/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.0ms
# video 1/1 (frame 19/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 mbs, 1 mbs_hotel, 1 sg_river, 32.3ms
# video 1/1 (frame 20/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.5ms
# video 1/1 (frame 21/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.7ms
# video 1/1 (frame 22/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.4ms
# video 1/1 (frame 23/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.1ms
# video 1/1 (frame 24/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.4ms
# video 1/1 (frame 25/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 35.5ms
# video 1/1 (frame 26/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 35.5ms
# video 1/1 (frame 27/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 36.4ms
# video 1/1 (frame 28/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 41.8ms
# video 1/1 (frame 29/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.0ms
# video 1/1 (frame 30/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 26.7ms
# video 1/1 (frame 31/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 32.1ms
# video 1/1 (frame 32/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 36.7ms
# video 1/1 (frame 33/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.1ms
# video 1/1 (frame 34/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 26.2ms
# video 1/1 (frame 35/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 29.2ms
# video 1/1 (frame 36/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 32.8ms
# video 1/1 (frame 37/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.2ms
# video 1/1 (frame 38/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 29.8ms
# video 1/1 (frame 39/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.6ms
# video 1/1 (frame 40/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 32.7ms
# video 1/1 (frame 41/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 26.4ms
# video 1/1 (frame 42/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 39.4ms
# video 1/1 (frame 43/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 34.0ms
# video 1/1 (frame 44/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 37.4ms
# video 1/1 (frame 45/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 41.1ms
# video 1/1 (frame 46/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.0ms
# video 1/1 (frame 47/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 40.1ms
# video 1/1 (frame 48/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.5ms
# video 1/1 (frame 49/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 45.1ms
# video 1/1 (frame 50/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.9ms
# video 1/1 (frame 51/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 25.3ms
# video 1/1 (frame 52/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 34.1ms
# video 1/1 (frame 53/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 43.7ms
# video 1/1 (frame 54/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 24.8ms
# video 1/1 (frame 55/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.3ms
# video 1/1 (frame 56/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.4ms
# video 1/1 (frame 57/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 46.3ms
# video 1/1 (frame 58/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.4ms
# video 1/1 (frame 59/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 25.9ms
# video 1/1 (frame 60/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.9ms
# video 1/1 (frame 61/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.0ms
# video 1/1 (frame 62/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 34.4ms
# video 1/1 (frame 63/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 37.3ms
# video 1/1 (frame 64/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 28.2ms
# video 1/1 (frame 65/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 26.2ms
# video 1/1 (frame 66/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 27.6ms
# video 1/1 (frame 67/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 24.4ms
# video 1/1 (frame 68/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.3ms
# video 1/1 (frame 69/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.2ms
# video 1/1 (frame 70/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.9ms
# video 1/1 (frame 71/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 25.5ms
# video 1/1 (frame 72/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 27.7ms
# video 1/1 (frame 73/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 36.9ms
# video 1/1 (frame 74/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 28.7ms
# video 1/1 (frame 75/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 29.0ms
# video 1/1 (frame 76/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 44.2ms
# video 1/1 (frame 77/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.7ms
# video 1/1 (frame 78/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 32.9ms
# video 1/1 (frame 79/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 32.5ms
# video 1/1 (frame 80/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.1ms
# video 1/1 (frame 81/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 32.1ms
# video 1/1 (frame 82/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 36.1ms
# video 1/1 (frame 83/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 36.6ms
# video 1/1 (frame 84/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 36.5ms
# video 1/1 (frame 85/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 27.3ms
# video 1/1 (frame 86/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 26.2ms
# video 1/1 (frame 87/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 28.7ms
# video 1/1 (frame 88/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 24.7ms
# video 1/1 (frame 89/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.1ms
# video 1/1 (frame 90/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.5ms
# video 1/1 (frame 91/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.9ms
# video 1/1 (frame 92/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 29.0ms
# video 1/1 (frame 93/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.3ms
# video 1/1 (frame 94/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 32.3ms
# video 1/1 (frame 95/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 28.8ms
# video 1/1 (frame 96/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.8ms
# video 1/1 (frame 97/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.7ms
# video 1/1 (frame 98/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 28.3ms
# video 1/1 (frame 99/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 42.4ms
# video 1/1 (frame 100/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.6ms
# video 1/1 (frame 101/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 25.4ms
# video 1/1 (frame 102/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 29.4ms
# video 1/1 (frame 103/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.5ms
# video 1/1 (frame 104/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.0ms
# video 1/1 (frame 105/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.3ms
# video 1/1 (frame 106/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 2 lv_marina_bays, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.7ms
# video 1/1 (frame 107/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.1ms
# video 1/1 (frame 108/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.6ms
# video 1/1 (frame 109/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river,
207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 41.1ms
# video 1/1 (frame 154/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.8ms
# video 1/1 (frame 155/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 36.0ms
# video 1/1 (frame 156/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.7ms
# video 1/1 (frame 157/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 29.8ms
# video 1/1 (frame 158/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 mbs, 1 mbs_hotel, 1 sg_river, 36.8ms
# video 1/1 (frame 159/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 mbs, 1 mbs_hotel, 1 sg_river, 34.2ms
# video 1/1 (frame 160/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 32.6ms
# video 1/1 (frame 161/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 27.9ms
# video 1/1 (frame 162/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 32.4ms
# video 1/1 (frame 163/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 mbs, 1 mbs_hotel, 1 sg_river, 28.7ms
# video 1/1 (frame 164/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.4ms
# video 1/1 (frame 165/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 mbs, 1 mbs_hotel, 1 sg_river, 27.2ms
# video 1/1 (frame 166/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 40.6ms
# video 1/1 (frame 167/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 29.0ms
# video 1/1 (frame 168/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.6ms
# video 1/1 (frame 169/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.2ms
# video 1/1 (frame 170/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 26.1ms
# video 1/1 (frame 171/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 32.8ms
# video 1/1 (frame 172/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.1ms
# video 1/1 (frame 173/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 mbs, 1 mbs_hotel, 1 sg_river, 36.7ms
# video 1/1 (frame 174/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 26.8ms
# video 1/1 (frame 175/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 26.2ms
# video 1/1 (frame 176/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 28.1ms
# video 1/1 (frame 177/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.2ms
# video 1/1 (frame 178/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 28.9ms
# video 1/1 (frame 179/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 28.4ms
# video 1/1 (frame 180/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 49.2ms
# video 1/1 (frame 181/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 28.2ms
# video 1/1 (frame 182/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 37.8ms
# video 1/1 (frame 183/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 27.5ms
# video 1/1 (frame 184/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.1ms
# video 1/1 (frame 185/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 30.1ms
# video 1/1 (frame 186/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 34.0ms
# video 1/1 (frame 187/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.2ms
# video 1/1 (frame 188/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 36.5ms
# video 1/1 (frame 189/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 36.1ms
# video 1/1 (frame 190/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.3ms
# video 1/1 (frame 191/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.0ms
# video 1/1 (frame 192/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 31.6ms
# video 1/1 (frame 193/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.2ms
# video 1/1 (frame 194/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 34.9ms
# video 1/1 (frame 195/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 53.4ms
# video 1/1 (frame 196/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 27.0ms
# video 1/1 (frame 197/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 27.3ms
# video 1/1 (frame 198/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.2ms
# video 1/1 (frame 199/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 34.3ms
# video 1/1 (frame 200/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 29.3ms
# video 1/1 (frame 201/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 2 helix_bridges, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 34.2ms
# video 1/1 (frame 202/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 27.6ms
# video 1/1 (frame 203/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 27.8ms
# video 1/1 (frame 204/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 34.3ms
# video 1/1 (frame 205/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 33.7ms
# video 1/1 (frame 206/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 36.4ms
# video 1/1 (frame 207/207) C:\Users\ngyin\Documents\NUS Stackables\SP 1\Practice Module (landmark recognition)\data\sample\online_video_1.mp4: 384x640 1 apple_marina_bay, 1 art_sci_museum, 1 helix_bridge, 1 lv_marina_bay, 1 mbs, 1 mbs_hotel, 1 sg_river, 38.1ms
# Speed: 4.2ms preprocess, 32.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Font path '<TTF_FONT_PATH>' not found. Using PIL's default font.
# VideoInfo(width=2562, height=1440, fps=25, total_frames=207)

# %% [markdown]
# # BYTETRACK ON LIVESTREAM

# %%
# Livestreaming

# # Define video capture (0 for webcam, or use an RTSP/HTTP stream URL)
# cap = cv2.VideoCapture(0)  # Change to 'rtsp://your_stream_url' for live streaming

# # Define annotators
# box_annotator = sv.BoxAnnotator()
# dot_annotator = sv.DotAnnotator(radius=15, outline_thickness=5, outline_color=sv.Color.from_hex('#FFFFFF'))
# rich_label_annotator = sv.RichLabelAnnotator(
#     font_path="<TTF_FONT_PATH>", font_size=35, text_position=sv.Position.TOP_CENTER,
#     text_padding=12, border_radius=15, smart_position=True
# )

# # Loop for livestreaming
# while cap.isOpened():
#     ret, frame = cap.read()
#     if not ret:
#         print("Failed to grab frame, exiting...")
#         break

#     # Run YOLO tracking on the current frame
#     results = model.track(frame, persist=True, tracker="bytetrack.yaml")

#     if results and len(results) > 0:
#         result = results[0]  # Process the first result

#         detections = sv.Detections.from_ultralytics(result)
#         detections = detections.with_nms(threshold=0.7, class_agnostic=False)

#         # Select highest confidence detection per class
#         detections_by_class = {}
#         for i in range(len(detections.class_id)):
#             class_id = detections.class_id[i]
#             if class_id not in detections_by_class or detections.confidence[i] > detections_by_class[class_id]['confidence']:
#                 detections_by_class[class_id] = {
#                     'xyxy': detections.xyxy[i],
#                     'confidence': detections.confidence[i],
#                     'class_id': class_id,
#                     'class_name': detections.data['class_name'][i]
#                 }

#         # Annotate frame
#         if len(detections_by_class) > 0:
#             filtered_xyxy = np.array([det['xyxy'] for det in detections_by_class.values()])
#             filtered_confidence = np.array([det['confidence'] for det in detections_by_class.values()])
#             filtered_class_id = np.array([det['class_id'] for det in detections_by_class.values()])
#             filtered_class_name = np.array([det['class_name'] for det in detections_by_class.values()])

#             filtered_detections = sv.Detections(
#                 xyxy=filtered_xyxy, confidence=filtered_confidence,
#                 class_id=filtered_class_id, data={'class_name': filtered_class_name}
#             )

#             labels = [f"{class_name} {confidence:.2f}" for class_name, confidence in zip(filtered_detections.data['class_name'], filtered_detections.confidence)]

#             annotated_frame = dot_annotator.annotate(frame, filtered_detections)
#             annotated_frame = rich_label_annotator.annotate(annotated_frame, filtered_detections, labels=labels)
#         else:
#             annotated_frame = frame  # No detections, keep original frame
#     else:
#         annotated_frame = frame  # No results, keep original frame

#     # Display the frame
#     cv2.imshow("Live Tracking", annotated_frame)

#     # Break the loop when 'q' is pressed
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# # Release resources
# cap.release()
# cv2.destroyAllWindows()

# %%
# # to visualize on frame 1
# frame_generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)
# test_f = next(frame_generator)
# sv.plot_image(test_f)
# # detections = sv.Detections.from_ultralytics(results).with_nms(threshold=0.7, class_agnostic=False)
# # detections
